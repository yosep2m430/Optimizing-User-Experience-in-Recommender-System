# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %%
df_metadata= pd.read_csv('/Users/josephlim/Desktop/Data Science/Capstone Projects/Capstone Project- Optimizing User Experience in Recommender System/Optimizing User Experience in Recommender System Data/movies_metadata.csv')
df_credits= pd.read_csv('/Users/josephlim/Desktop/Data Science/Capstone Projects/Capstone Project- Optimizing User Experience in Recommender System/Optimizing User Experience in Recommender System Data/credits.csv')
# Out:
# /var/folders/z9/t15ddpld70nc5qf41442lpr80000gn/T/ipykernel_2173/2898102119.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_metadata= pd.read_csv('/Users/josephlim/Desktop/Data Science/Capstone Projects/Capstone Project- Optimizing User Experience in Recommender System/Optimizing User Experience in Recommender System Data/movies_metadata.csv')

# %%
df_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
df_credits.shape
# Out:
# (45476, 3)

# %%
df_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df_metadata.shape
# Out:
# (45466, 24)

# %%
df_metadata['status'].unique()
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
df_metadata= df_metadata.loc[df_metadata['status']=='Released']

# %%
df_metadata['status'].unique()
# Out:
# array(['Released'], dtype=object)

# %%
df_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45014 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45014 non-null  object
#  1   belongs_to_collection  4466 non-null   object
#  2   budget                 45014 non-null  object
#  3   genres                 45014 non-null  object
#  4   homepage               7706 non-null   object
#  5   id                     45014 non-null  object
#  6   imdb_id                44999 non-null  object
#  7   original_language      45004 non-null  object
#  8   original_title         45014 non-null  object
#  9   overview               44094 non-null  object
#  10  popularity             45014 non-null  object
#  11  poster_path            44641 non-null  object
#  12  production_companies   45014 non-null  object
#  13  production_countries   45014 non-null  object
# ...

# %%
df_metadata.shape
# Out:
# (45014, 24)

# %%
df_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df_metadata=df_metadata.astype({'id':int})

# %%
na_col=df_metadata.columns[df_metadata.columns!= 'imdb_id']
df_metadata[na_col]=df_metadata[na_col].replace({np.nan:'Not Available'})

# %%
df_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45014 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45014 non-null  object
#  1   belongs_to_collection  45014 non-null  object
#  2   budget                 45014 non-null  object
#  3   genres                 45014 non-null  object
#  4   homepage               45014 non-null  object
#  5   id                     45014 non-null  int64
#  6   imdb_id                44999 non-null  object
#  7   original_language      45014 non-null  object
#  8   original_title         45014 non-null  object
#  9   overview               45014 non-null  object
#  10  popularity             45014 non-null  object
#  11  poster_path            45014 non-null  object
#  12  production_companies   45014 non-null  object
#  13  production_countries   45014 non-null  object
# ...

# %%
df1= df_metadata.loc[df_metadata['imdb_id'].isnull()]

# %%
df1
# Out:
#        adult                              belongs_to_collection   budget  \
# 8966   False                                      Not Available  1000000
# 13757  False                                      Not Available        0
# 13821  False  {'id': 75014, 'name': 'How I Unleashed World W...        0
# 17382  False                                      Not Available  2500000
# 18959  False                                      Not Available        0
# 19322  False                                      Not Available        0
# 20806  False                                      Not Available        0
# 20937  False                                      Not Available        0
# 21916  False                                      Not Available        0
# 23744  False  {'id': 246207, 'name': 'Gunbuster Collection',...        0
# 33753  False                                      Not Available        0
# 36955  False                                      Not Available        0
# ...

# %%
df_metadata['imdb_id']=df_metadata['imdb_id'].replace({np.nan:'Not Available'})

# %%
df= df_credits.merge(df_metadata, on='id')

# %%
df.to_csv('metatadata_credits_cleaned.csv')
